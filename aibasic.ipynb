# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0.6B")
tokens = tokenizer("What is the capital of France?", return_tensors="pt")
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 7
#       3 load_dotenv()
#       4 os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")
#       5 from transformers import AutoTokenizer
#       6 tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0.6B")
# ----> 7 tokens = tokenizer("What is the capital of France?", return_tensors="pt")
#       8 print(tokens)
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:2513, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, tokenizer_kwargs, **kwargs)
#    2511     if not self._in_target_context_manager and hasattr(self, "_switch_to_input_mode"):
#    2512         self._switch_to_input_mode()
# -> 2513     encodings = self._encode_plus(
#    2514         text=text,
#    2515         text_pair=text_pair,
#    2516         padding_strategy=padding_strategy,
#    2517         truncation_strategy=truncation_strategy,
#    2518         max_length=max_length,
#    2519         **all_kwargs,
#    2520     )
#    2521 if text_target is not None:
#    2522     if hasattr(self, "_switch_to_target_mode"):
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\tokenization_utils_tokenizers.py:997, in TokenizersBackend._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     994 for input_ids in sanitized_tokens["input_ids"]:
#     995     self._eventual_warn_about_too_long_sequence(input_ids, max_length, verbose)
# --> 997 batched_output = BatchEncoding(sanitized_tokens, sanitized_encodings, tensor_type=return_tensors)
#     999 # If single input, remove the batch dimension (unless returning overflowing tokens)
#    1000 if not is_batched and return_tensors is None and not return_overflowing_tokens:
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:242, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     238     n_sequences = encoding[0].n_sequences
#     240 self._n_sequences = n_sequences
# --> 242 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:693, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     691 if tensor_type == TensorType.PYTORCH:
#     692     if not is_torch_available():
# --> 693         raise ImportError("Unable to convert output to PyTorch tensors format, PyTorch is not installed.")
#     694     import torch
#     696     def as_tensor(value, dtype=None):
#
# ImportError: Unable to convert output to PyTorch tensors format, PyTorch is not installed.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="hf-inference",
    api_key=os.getenv("HF_TOKEN")
)

result = client.sentence_similarity(
    sentence="That is a happy person",
    other_sentences=[
        "That is a happy dog",
        "That is a very happy person",
        "Today is a sunny day"
    ],
    model="google/embeddinggemma-300m"
)
 
print(result)
# Out:
# [0.9158520698547363, 0.9813192486763, 0.7847327589988708]

# %%
from sentence_transformers import SentenceTransformer
 
model = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B")
 
sentences = [
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium."
]
embeddings = model.encode(sentences)
 
similarities = model.similarity(embeddings, embeddings)
print(similarities.shape)
print(len(embeddings))
# Out:
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2
#       3 model = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B")
#       4
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#      18     CrossEncoderModelCardData,
#      19     CrossEncoderTrainer,
#      20     CrossEncoderTrainingArguments,
#      21 )
#      22 from sentence_transformers.sentence_transformer.datasets import ParallelSentencesDataset, SentencesDataset
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\sentence_transformers\base\__init__.py:4
#       1 from __future__ import annotations
#       3 from .data_collator import BaseDataCollator
# ----> 4 from .model import BaseModel
#       5 from .peft_mixin import PeftAdapterMixin
#       6 from .sampler import (
#       7     DefaultBatchSampler,
#       8     GroupByLabelBatchSampler,
#    (...)     12     RoundRobinBatchSampler,
#      13 )
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\sentence_transformers\base\model.py:34
#      32 from sentence_transformers.base.model_card import BaseModelCardData, generate_model_card
#      33 from sentence_transformers.base.modules import Module, Router, Transformer
# ---> 34 from sentence_transformers.base.peft_mixin import PeftAdapterMixin
#      35 from sentence_transformers.util import (
#      36     get_device_name,
#      37     import_module_class,
#    (...)     40     save_to_hub_args_decorator,
#      41 )
#      42 from sentence_transformers.util.misc import ORIGINAL_TRANSFORMER_MODELS
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\sentence_transformers\base\peft_mixin.py:5
#       1 from __future__ import annotations
#       3 from functools import wraps
# ----> 5 from transformers.integrations.peft import PeftAdapterMixin as PeftAdapterMixinTransformers
#       8 def peft_wrapper(func):
#       9     """Wrapper to call the method on the auto_model with a check for PEFT compatibility."""
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\integrations\peft.py:25
#      22 from safetensors import safe_open
#      24 from .._typing import PeftConfigLike
# ---> 25 from ..conversion_mapping import (
#      26     _MODEL_TO_CONVERSION_PATTERN,
#      27     get_checkpoint_conversion_mapping,
#      28     get_model_conversion_mapping,
#      29 )
#      30 from ..core_model_loading import (
#      31     Concatenate,
#      32     ConversionOps,
#    (...)     36     WeightRenaming,
#      37 )
#      38 from ..utils import (
#      39     CONFIG_NAME,
#      40     cached_file,
#    (...)     47     logging,
#      48 )
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\conversion_mapping.py:21
#      18 from copy import deepcopy
#      19 from typing import TYPE_CHECKING
# ---> 21 from .core_model_loading import (
#      22     Chunk,
#      23     Concatenate,
#      24     ErnieFuseAndSplitTextVisionExperts,
#      25     MergeModulelist,
#      26     PrefixChange,
#      27     Transpose,
#      28     WeightConverter,
#      29     WeightRenaming,
#      30     WeightTransform,
#      31 )
#      34 if TYPE_CHECKING:
#      35     from .modeling_utils import PreTrainedModel
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\core_model_loading.py:33
#      29 from typing import TYPE_CHECKING, Any
#      31 import torch
# ---> 33 from .integrations.accelerate import get_device, offload_weight
#      34 from .integrations.tensor_parallel import ALL_PARALLEL_STYLES
#      35 from .utils import is_env_variable_true
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\integrations\accelerate.py:62
#      51     from ..quantizers import HfQuantizer
#      54 logger = logging.get_logger(__name__)
#      57 def get_module_size_with_ties(
#      58     tied_params,
#      59     module_size,
#      60     module_sizes,
#      61     modules_to_treat,
# ---> 62 ) -> tuple[int, list[str], list[nn.Module]]:
#      63     """
#      64     Calculate the total size of a module, including its tied parameters.
#      65
#    (...)     74         tied modules.
#      75     """
#      76     if len(tied_params) < 1:
#
# NameError: name 'nn' is not defined

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from google import genai
from google.genai import types
google_api_key = os.getenv("google_api_key")

# For Vertex AI:
# PROJECT_ID='<add_here>'
# client = genai.Client(vertexai=True, project=PROJECT_ID, location='us-central1')

client = genai.Client(api_key=google_api_key)

# with open("example.png", "rb") as f:
#     image_bytes = f.read()

# with open("sample.mp3", "rb") as f:
#     audio_bytes = f.read()

# Embed text, image, and audio 
result = client.models.embed_content(
    model="gemini-embedding-2-preview",
    contents=[
        "What is the meaning of life?",
        # types.Part.from_bytes(
        #     data=image_bytes,
        #     mime_type="image/png",
        # ),
        # types.Part.from_bytes(
        #     data=audio_bytes,
        #     mime_type="audio/mpeg",
        # ),
    ],
)

print(result.embeddings)
# Out:
# [ContentEmbedding(
#   values=[
#     -0.016332133,
#     -0.0043764366,
#     -0.0011324773,
#     -0.011240026,
#     0.00029597108,
#     <... 3067 more items ...>,
#   ]
# )]

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.getenv("HF_TOKEN"),
)

completion = client.chat.completions.create(
    model="Qwen/Qwen3-0.6B:featherless-ai",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The capital of France is Paris.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning="\nOkay, the user is asking about the capital of France. Let me think. I remember that France is a country in Europe, and its capital is Paris. But wait, I should double-check to make sure. I think Paris is the correct answer. The capital is indeed Paris. No, wait, maybe I got it mixed up with another city? No, I don't think so. The capital of France is Paris. Yeah, I'm pretty sure about this. So the answer should be Paris.\n")

# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
 
 
client = genai.Client(api_key=os.getenv("google_api_key"))
 
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain machine learning in simple words"
)
 
print(response.text)
# Out:
# Imagine you want to teach a computer to do something, but instead of giving it a *long, detailed list of every single instruction* (like "if X happens, do Y; if Z happens, do A"), you teach it by showing it *examples*.
#
# That's machine learning in a nutshell!
#
# **Here's the breakdown:**
#
# 1.  **Learning from Examples:** Just like a baby learns what a "cat" is by seeing many different cats (big, small, black, white) and hearing "cat," a machine learning system learns by being fed lots and lots of data (examples).
#
# 2.  **Finding Patterns:** The computer then analyzes all these examples to find hidden patterns and relationships within the data. It's trying to figure out the "rules" for itself, without you explicitly telling it every rule.
#
# 3.  **Making Predictions/Decisions:** Once it has learned these patterns, it can use them to make predictions or decisions about *new* data it has never seen before.
#
# **Think of it like this:**
#
# *   **Teaching a computer to spot spam email:** Instead of you writing a rule for every single spam word or phrase, you show the computer thousands of emails labeled "spam" and thousands labeled "not spam." The computer then learns what typical spam emails look like (common words, sender patterns, etc.). From then on, when a new email arrives, it can use its learned patterns to predict whether it's spam or not.
#
# **In simple words:**
#
# Machine learning is a way of **teaching computers to learn from experience (data) and make predictions or decisions, without being explicitly programmed for every single possibility.** It's about letting the computer discover its own rules and insights.
#
# **Common examples you use every day:**
#
# *   **Recommendation systems:** Netflix suggesting movies, Amazon recommending products. (It learned what you and similar people like based on past choices).
# *   **Spam filters:** Catching junk mail. (It learned what spam looks like).
# *   **Voice assistants:** Siri, Alexa understanding your words. (It learned patterns in speech).
# *   **Facial recognition:** Unlocking your phone with your face. (It learned the unique features of your face).

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
 
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0.6B")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-0.6B")
messages = [
    {"role": "user", "content": "tell me about nepal?"},
]
inputs = tokenizer.apply_chat_template(
	messages,
	add_generation_prompt=True,
	tokenize=True,
	return_dict=True,
	return_tensors="pt",
).to(model.device)
 
outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0][inputs["input_ids"].shape[-1]:]))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 4
#       1 from transformers import AutoTokenizer, AutoModelForCausalLM
#       2
#       3 tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0.6B")
# ----> 4 model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-0.6B")
#       5 messages = [
#       6     {"role": "user", "content": "tell me about nepal?"},
#       7 ]
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\utils\import_utils.py:2077, in DummyObject.__getattribute__(cls, key)
#    2075 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2076     return super().__getattribute__(key)
# -> 2077 requires_backends(cls, cls._backends)
#
# File c:\Learning\BATCH-15\.venv\Lib\site-packages\transformers\utils\import_utils.py:2063, in requires_backends(obj, backends)
#    2060         failed.append(msg.format(name))
#    2062 if failed:
# -> 2063     raise ImportError("".join(failed))
#
# ImportError:
# AutoModelForCausalLM requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %%
generative pretrained transformer
